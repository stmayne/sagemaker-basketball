# %%
bucket = 'nba-game-prediction-smayne'
prefix = 'nba-game-prediction-smayne/DEMO-linear-dm'
 
# Define IAM role
import boto3
import re
from sagemaker import get_execution_role

role = get_execution_role()

# %%
import numpy as np                                # For matrix operations and numerical processing
import pandas as pd                               # For munging tabular data
import matplotlib.pyplot as plt                   # For charts and visualizations
from IPython.display import Image                 # For displaying images in the notebook
from IPython.display import display               # For displaying outputs in the notebook
from time import gmtime, strftime                 # For labeling SageMaker models, endpoints, etc.
import sys                                        # For writing outputs to notebook
import math                                       # For ceiling function
import json                                       # For parsing hosting outputs
import os                                         # For manipulating filepath names
import io
import sagemaker.amazon.common as smac
import sagemaker                                  # Amazon SageMaker's Python SDK provides many helper functions
from sagemaker.predictor import csv_serializer    # Converts strings for HTTP POST requests on inference

# %%
s3 = boto3.resource('s3')
object = s3.Object(bucket,'basketball_predictions_112119.csv')

# %%
data = pd.read_csv(object.get()['Body'])
pd.set_option('display.max_columns', 7)     # Make sure we can see all of the columns
pd.set_option('display.max_rows', 15)         # Keep the output on one page
data
# Out:
#     point_diff (N)  team1_elo (N)  team2_elo (N)  team1_away_percentage (N)  \
# 0               12           1493           1482                      0.333
# 1              -19           1434           1464                      0.434
# 2               19           1397           1319                      0.333
# 3              -10           1449           1667                      0.166
# 4              -14           1463           1505                      0.318
# 5               18           1271           1225                      0.240
# 6               18           1654           1270                      0.560
# ..             ...            ...            ...                        ...
# 45             -32           1285           1654                      0.238
# 46             -17           1429           1470                      0.437
# 47               9           1459           1532                      0.444
# 48               3           1584           1305                      0.611
# 49              -6           1469           1583                      0.157
# 50              26           1641           1272                      0.454
# 51             -21           1467           1498                      0.200
#
#     team1_last10 (N)  team2_home_percentage (N)  team2_last10 (N)
# 0                0.8                      0.550               0.3
# 1                0.5                      0.541               0.8
# 2                0.3                      0.380               0.3
# 3                0.3                      0.840               0.8
# 4                0.3                      0.652               0.7
# 5                0.1                      0.217               0.1
# 6                0.5                      0.210               0.1
# ..               ...                        ...               ...
# 45               0.5                      0.850               0.8
# 46               0.5                      0.667               0.4
# 47               0.7                      0.555               0.2
# 48               0.4                      0.263               0.7
# 49               0.3                      0.705               0.5
# 50               0.5                      0.263               0.1
# 51               0.4                      0.421               0.7
#
# [52 rows x 7 columns]

# %%
data = data.astype(float)
data
# Out:
#     point_diff (N)  team1_elo (N)  team2_elo (N)  team1_away_percentage (N)  \
# 0             12.0         1493.0         1482.0                      0.333
# 1            -19.0         1434.0         1464.0                      0.434
# 2             19.0         1397.0         1319.0                      0.333
# 3            -10.0         1449.0         1667.0                      0.166
# 4            -14.0         1463.0         1505.0                      0.318
# 5             18.0         1271.0         1225.0                      0.240
# 6             18.0         1654.0         1270.0                      0.560
# ..             ...            ...            ...                        ...
# 45           -32.0         1285.0         1654.0                      0.238
# 46           -17.0         1429.0         1470.0                      0.437
# 47             9.0         1459.0         1532.0                      0.444
# 48             3.0         1584.0         1305.0                      0.611
# 49            -6.0         1469.0         1583.0                      0.157
# 50            26.0         1641.0         1272.0                      0.454
# 51           -21.0         1467.0         1498.0                      0.200
#
#     team1_last10 (N)  team2_home_percentage (N)  team2_last10 (N)
# 0                0.8                      0.550               0.3
# 1                0.5                      0.541               0.8
# 2                0.3                      0.380               0.3
# 3                0.3                      0.840               0.8
# 4                0.3                      0.652               0.7
# 5                0.1                      0.217               0.1
# 6                0.5                      0.210               0.1
# ..               ...                        ...               ...
# 45               0.5                      0.850               0.8
# 46               0.5                      0.667               0.4
# 47               0.7                      0.555               0.2
# 48               0.4                      0.263               0.7
# 49               0.3                      0.705               0.5
# 50               0.5                      0.263               0.1
# 51               0.4                      0.421               0.7
#
# [52 rows x 7 columns]

# %%
model_data = pd.get_dummies(data) # Convert categorical variables to sets of indicators
model_data
# Out:
#     point_diff (N)  team1_elo (N)  team2_elo (N)  team1_away_percentage (N)  \
# 0             12.0         1493.0         1482.0                      0.333
# 1            -19.0         1434.0         1464.0                      0.434
# 2             19.0         1397.0         1319.0                      0.333
# 3            -10.0         1449.0         1667.0                      0.166
# 4            -14.0         1463.0         1505.0                      0.318
# 5             18.0         1271.0         1225.0                      0.240
# 6             18.0         1654.0         1270.0                      0.560
# ..             ...            ...            ...                        ...
# 45           -32.0         1285.0         1654.0                      0.238
# 46           -17.0         1429.0         1470.0                      0.437
# 47             9.0         1459.0         1532.0                      0.444
# 48             3.0         1584.0         1305.0                      0.611
# 49            -6.0         1469.0         1583.0                      0.157
# 50            26.0         1641.0         1272.0                      0.454
# 51           -21.0         1467.0         1498.0                      0.200
#
#     team1_last10 (N)  team2_home_percentage (N)  team2_last10 (N)
# 0                0.8                      0.550               0.3
# 1                0.5                      0.541               0.8
# 2                0.3                      0.380               0.3
# 3                0.3                      0.840               0.8
# 4                0.3                      0.652               0.7
# 5                0.1                      0.217               0.1
# 6                0.5                      0.210               0.1
# ..               ...                        ...               ...
# 45               0.5                      0.850               0.8
# 46               0.5                      0.667               0.4
# 47               0.7                      0.555               0.2
# 48               0.4                      0.263               0.7
# 49               0.3                      0.705               0.5
# 50               0.5                      0.263               0.1
# 51               0.4                      0.421               0.7
#
# [52 rows x 7 columns]

# %%
split_train = int(len(model_data) * 0.6)
split_test = int(len(model_data) * 0.8)

train_y = model_data['point_diff (N)']#[:split_train]
train_X = model_data.drop('point_diff (N)', axis=1)#[:split_train, ].as_matrix()
#validation_y = model_data['point_diff (N)'][split_train:split_test]
#validation_X = model_data.drop('point_diff (N)', axis=1).iloc[split_train:split_test, ].as_matrix()
#test_y = model_data['point_diff (N)'][split_test:]
#test_X = model_data.drop('point_diff (N)', axis=1).iloc[split_test:, ].as_matrix()

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
container = get_image_uri(boto3.Session().region_name, 'linear-learner')

# %%
buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(buf, np.array(train_X).astype('float32'), np.array(train_y).astype('float32'))
buf.seek(0)
key = 'linear_train.data'
boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', key)).upload_fileobj(buf)
s3_train_data = 's3://{}/{}/train/{}'.format(bucket, prefix, key)

#buf = io.BytesIO()
#smac.write_numpy_to_dense_tensor(buf, np.array(validation_X).astype('float32'), np.array(validation_y).astype('float32'))
#buf.seek(0)
#key = 'linear_validation.data'
#boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'validation', key)).upload_fileobj(buf)
#s3_validation_data = 's3://{}/{}/validation/{}'.format(bucket, prefix, key)

# %%
sess = sagemaker.Session()

linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.m5.large',
                                       output_path='s3://{}/{}/output'.format(bucket, prefix),
                                       sagemaker_session=sess)
linear.set_hyperparameters(feature_dim=6,
                           mini_batch_size=1,
                           predictor_type='regressor',
                           epochs=3,
                           loss='squared_loss')

linear.fit({'train': s3_train_data})
# Out:
# INFO:sagemaker:Creating training-job with name: linear-learner-2019-01-22-19-08-39-271
# 2019-01-22 19:08:39 Starting - Starting the training job...
# 2019-01-22 19:08:42 Starting - Launching requested ML instances......
# 2019-01-22 19:10:08 Starting - Preparing the instances for training......
# 2019-01-22 19:11:07 Downloading - Downloading input data...
# 2019-01-22 19:11:35 Training - Training image download completed. Training in progress..
# Docker entrypoint called with argument(s): train
# [01/22/2019 19:11:37 INFO 139640663308096] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [01/22/2019 19:11:37 INFO 139640663308096] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'epochs': u'3', u'loss': u'squared_loss', u'feature_dim': u'6', u'mini_batch_size': u'1', u'predictor_type': u'regressor'}
# [01/22/2019 19:11:37 INFO 139640663308096] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'3', u'feature_dim': u'6', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'regressor', u'beta_1': u'auto', u'loss': u'squared_loss', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [01/22/2019 19:11:37 WARNING 139640663308096] Loggers have already been setup.
# Process 1 is a worker.
# [01/22/2019 19:11:37 INFO 139640663308096] Using default worker.
# [2019-01-22 19:11:37.381] [tensorio] [info] batch={"data_pipeline": "/opt/ml/input/data/train", "num_examples": 1, "features": [{"name": "label_values", "shape": [1], "storage_type": "dense"}, {"name": "values", "shape": [6], "storage_type": "dense"}]}
# [2019-01-22 19:11:37.398] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 0, "duration": 17, "num_examples": 1}
# [01/22/2019 19:11:37 INFO 139640663308096] Create Store: local
# [2019-01-22 19:11:37.505] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 1, "duration": 106, "num_examples": 52}
# [01/22/2019 19:11:37 INFO 139640663308096] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f00510804d0>
# [01/22/2019 19:11:37 INFO 139640663308096] Scaling model computed with parameters:
#  {'stdev_weight':
# [ 124.29714203  116.77496338    0.13849169    0.21068884    0.1855236
#     0.21338356]
# <NDArray 6 @cpu(0)>, 'stdev_label':
# [ 13.30107594]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [-6.34615421]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [  1.47015381e+03   1.49573071e+03   3.79769325e-01   4.55769241e-01
#    5.97134709e-01   5.15384614e-01]
# <NDArray 6 @cpu(0)>}
# [01/22/2019 19:11:37 INFO 139640663308096] nvidia-smi took: 0.0251359939575 secs to identify 0 gpus
# [01/22/2019 19:11:37 INFO 139640663308096] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 52, "sum": 52.0, "min": 52}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max":
"Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1548184298.346067}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.043557523427388, "sum": 1.043557523427388, "min": 1.043557523427388}}, "EndTime": 1548184298.346146, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1548184298.346133}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.065829316745154, "sum": 1.065829316745154, "min": 1.065829316745154}}, "EndTime": 1548184298.346212, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1548184298.346199}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0638677834067494, "sum": 1.0638677834067494, "min": 1.0638677834067494}}, "EndTime": 1548184298.346272, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1548184298.346258}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.059870745610589, "sum": 1.059870745610589, "min": 1.059870745610589}}, "EndTime": 1548184298.346317, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1548184298.346307}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.149258010322228, "sum": 1.149258010322228, "min": 1.149258010322228}}, "EndTime": 1548184298.346358, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1548184298.346348}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1597655800421938, "sum": 1.1597655800421938, "min": 1.1597655800421938}}, "EndTime": 1548184298.346414, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1548184298.346401}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1566528034880041, "sum": 1.1566528034880041, "min": 1.1566528034880041}}, "EndTime": 1548184298.34648, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1548184298.346448}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.14864260244828, "sum": 1.14864260244828, "min": 1.14864260244828}}, "EndTime": 1548184298.346529, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1548184298.346517}
#
# [01/22/2019 19:11:38 INFO 139640663308096] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=1.01129451825
# [01/22/2019 19:11:38 INFO 139640663308096] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=0.881307628708
# [01/22/2019 19:11:38 INFO 139640663308096] Epoch 0: Loss improved. Updating best model
# [01/22/2019 19:11:38 INFO 139640663308096] #progress_metric: host=algo-1, completed 33 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 52, "sum": 52.0, "min": 52}, "Number of Batches Since Last Reset": {"count": 1, "max": 52, "sum": 52.0, "min": 52}, "Number of Records Since Last Reset": {"count": 1, "max": 52, "sum": 52.0, "min": 52}, "Total Batches Seen": {"count": 1, "max": 105, "sum": 105.0, "min": 105}, "Total Records Seen": {"count": 1, "max": 105, "sum": 105.0, "min": 105}, "Max Records Seen Between Resets": {"count": 1, "max": 52, "sum": 52.0, "min": 52}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1548184298.349942, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1548184297.616911}
#
# [01/22/2019 19:11:38 INFO 139640663308096] #throughput_metric: host=algo-1, train throughput=70.9259456302 records/second
# [2019-01-22 19:11:38.350] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 2, "duration": 733, "num_examples": 52}
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.804570881046507, "sum": 0.804570881046507, "min": 0.804570881046507}}, "EndTime": 1548184299.068936, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1548184299.068874}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7243183760259014, "sum": 0.7243183760259014, "min": 0.7243183760259014}}, "EndTime": 1548184299.069011, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1548184299.068997}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7395209141720372, "sum": 0.7395209141720372, "min": 0.7395209141720372}}, "EndTime": 1548184299.069255, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1548184299.069234}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7617096244179126, "sum": 0.7617096244179126, "min": 0.7617096244179126}}, "EndTime": 1548184299.069307, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1548184299.069295}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.400394276926258, "sum": 1.400394276926258, "min": 1.400394276926258}}, "EndTime": 1548184299.069382, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1548184299.069369}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.440751896657625, "sum": 1.440751896657625, "min": 1.440751896657625}}, "EndTime": 1548184299.069427, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1548184299.069416}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.3469412691472546, "sum": 1.3469412691472546, "min": 1.3469412691472546}}, "EndTime": 1548184299.069517, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1548184299.069504}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.4471775213012454, "sum": 1.4471775213012454, "min": 1.4471775213012454}}, "EndTime": 1548184299.069564, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1548184299.069552}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.
#early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=mse_objective, value=0.724318376026
# [01/22/2019 19:11:39 INFO 139640663308096] Epoch 1: Loss improved. Updating best model
# [01/22/2019 19:11:39 INFO 139640663308096] #progress_metric: host=algo-1, completed 66 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 52, "sum": 52.0, "min": 52}, "Number of Batches Since Last Reset": {"count": 1, "max": 52, "sum": 52.0, "min": 52}, "Number of Records Since Last Reset": {"count": 1, "max": 52, "sum": 52.0, "min": 52}, "Total Batches Seen": {"count": 1, "max": 157, "sum": 157.0, "min": 157}, "Total Records Seen": {"count": 1, "max": 157, "sum": 157.0, "min": 157}, "Max Records Seen Between Resets": {"count": 1, "max": 52, "sum": 52.0, "min": 52}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1548184299.074072, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1548184298.350335}
#
# [01/22/2019 19:11:39 INFO 139640663308096] #throughput_metric: host=algo-1, train throughput=71.8309417 records/second
# [2019-01-22 19:11:39.074] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 3, "duration": 723, "num_examples": 52}
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7170719266152725, "sum": 0.7170719266152725, "min": 0.7170719266152725}}, "EndTime": 1548184299.838026, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.837929}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6715909367418275, "sum": 0.6715909367418275, "min": 0.6715909367418275}}, "EndTime": 1548184299.838565, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.838532}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6711581964515901, "sum": 0.6711581964515901, "min": 0.6711581964515901}}, "EndTime": 1548184299.83888, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.838854}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7018481275299564, "sum": 0.7018481275299564, "min": 0.7018481275299564}}, "EndTime": 1548184299.839177, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.839151}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.3391901903213204, "sum": 1.3391901903213204, "min": 1.3391901903213204}}, "EndTime": 1548184299.839466, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.839441}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.5209245268286815, "sum": 1.5209245268286815, "min": 1.5209245268286815}}, "EndTime": 1548184299.839689, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.839665}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.3038480293460173, "sum": 1.3038480293460173, "min": 1.3038480293460173}}, "EndTime": 1548184299.83993, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.839907}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.5341566202436507, "sum": 1.5341566202436507, "min": 1.5341566202436507}}, "EndTime": 1548184299.840155, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.840132}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6907342298875917, "sum": 0.6907342298875917, "min": 0.6907342298875917}}, "EndTime": 1548184299.840367, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.840345}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7011875947405665, "sum": 0.7011875947405665, "min": 0.7011875947405665}}, "EndTime": 1548184299.840569, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.840547}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7113877152531551, "sum": 0.7113877152531551, "min": 0.7113877152531551}}, "EndTime": 1548184299.840803, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.840766}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7049959580927652, "sum": 0.7049959580927652, "min": 0.7049959580927652}}, "EndTime": 1548184299.84101, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.840988}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.3178026211434581, "sum": 1.3178026211434581, "min": 1.3178026211434581}}, "EndTime": 1548184299.841213, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.841191}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.5308484336311756, "sum": 1.5308484336311756, "min": 1.5308484336311756}}, "EndTime": 1548184299.841412, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.841389}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.3122200798212982, "sum": 1.3122200798212982, "min": 1.3122200798212982}}, "EndTime": 1548184299.84162, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.841597}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.4780143864577089, "sum": 1.4780143864577089, "min": 1.4780143864577089}}, "EndTime": 1548184299.841822, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.841801}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7501365308148357, "sum": 0.7501365308148357, "min": 0.7501365308148357}}, "EndTime": 1548184299.842022, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.842001}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7524801875025822, "sum": 0.7524801875025822, "min": 0.7524801875025822}}, "EndTime": 1548184299.84222, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.842198}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7404010034022996, "sum": 0.7404010034022996, "min": 0.7404010034022996}}, "EndTime": 1548184299.842421, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.8424}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7384916250862611, "sum": 0.7384916250862611, "min": 0.7384916250862611}}, "EndTime": 1548184299.842616, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.842595}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8762333184803048, "sum": 0.8762333184803048, "min": 0.8762333184803048}}, "EndTime": 1548184299.842845, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.842823}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8673849602183998, "sum": 0.8673849602183998, "min": 0.8673849602183998}}, "EndTime": 1548184299.843053, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.843031}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8757419236471133, "sum": 0.8757419236471133, "min": 0.8757419236471133}}, "EndTime": 1548184299.843246, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.843224}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8669683694845914, "sum": 0.8669683694845914, "min": 0.8669683694845914}}, "EndTime": 1548184299.843439, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.843418}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0414656733869028, "sum": 1.0414656733869028, "min": 1.0414656733869028}}, "EndTime": 1548184299.843636, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.843614}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0484854264851982, "sum": 1.0484854264851982, "min": 1.0484854264851982}}, "EndTime": 1548184299.843836, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.843814}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0404024097476325, "sum": 1.0404024097476325, "min": 1.0404024097476325}}, "EndTime": 1548184299.844035, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.844013}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0500016363646585, "sum": 1.0500016363646585, "min": 1.0500016363646585}}, "EndTime": 1548184299.84423, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.844209}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0881645775569688, "sum": 1.0881645775569688, "min": 1.0881645775569688}}, "EndTime": 1548184299.84443, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.844408}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.121688746106184, "sum": 1.121688746106184, "min": 1.121688746106184}}, "EndTime": 1548184299.84463, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.844609}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.085211248223109, "sum": 1.085211248223109, "min": 1.085211248223109}}, "EndTime": 1548184299.844849, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.844827}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.118670988750147, "sum": 1.118670988750147, "min": 1.118670988750147}}, "EndTime": 1548184299.845049, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.845027}
#
# [01/22/2019 19:11:39 INFO 139640663308096] #quality_metric: host=algo-1, epoch=2, train mse_objective <loss>=0.717071926615
# [01/22/2019 19:11:39 INFO 139640663308096] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=mse_objective, value=0.671158196452
# [01/22/2019 19:11:39 INFO 139640663308096] Epoch 2: Loss improved. Updating best model
# [01/22/2019 19:11:39 INFO 139640663308096] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 52, "sum": 52.0, "min": 52}, "Number of Batches Since Last Reset": {"count": 1, "max": 52, "sum": 52.0, "min": 52}, "Number of Records Since Last Reset": {"count": 1, "max": 52, "sum": 52.0, "min": 52}, "Total Batches Seen": {"count": 1, "max": 209, "sum": 209.0, "min": 209}, "Total Records Seen": {"count": 1, "max": 209, "sum": 209.0, "min": 209}, "Max Records Seen Between Resets": {"count": 1, "max": 52, "sum": 52.0, "min": 52}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1548184299.849076, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1548184299.074442}
#
# [01/22/2019 19:11:39 INFO 139640663308096] #throughput_metric: host=algo-1, train throughput=67.1064894627 records/second
# [01/22/2019 19:11:39 WARNING 139640663308096] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [01/22/2019 19:11:39 WARNING 139640663308096] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-01-22 19:11:39.849] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 4, "duration": 775, "num_examples": 52}
# [2019-01-22 19:11:39.850] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 5, "duration": 0, "num_examples": 1}
# [01/22/2019 19:11:39 INFO 139640663308096] #train_score (algo-1) : ('mse_objective', 107.77905261344634)
# [01/22/2019 19:11:39 INFO 139640663308096] #quality_metric: host=algo-1, train mse_objective <loss>=107.779052613
# [01/22/2019 19:11:39 INFO 139640663308096] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 0.0001}
# [01/22/2019 19:11:39 INFO 139640663308096] Saved checkpoint to "/tmp/tmpvvfc4s/mx-mod-0000.params"
# [01/22/2019 19:11:39 INFO 139640663308096] Test data is not provided.
# [2019-01-22 19:11:39.895] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 6, "duration": 41, "num_examples": 52}
# [2019-01-22 19:11:39.895] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "duration": 2395, "num_epochs": 7, "num_examples": 262}
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 2619.03715133667, "sum": 2619.03715133667, "min": 2619.03715133667}, "finalize.time": {"count": 1, "max": 34.38997268676758, "sum": 34.38997268676758, "min": 34.38997268676758}, "initialize.time": {"count": 1, "max": 234.3909740447998, "sum": 234.3909740447998, "min": 234.3909740447998}, "check_early_stopping.time": {"count": 3, "max": 1.252889633178711, "sum": 3.08990478515625, "min": 0.9169578552246094}, "setuptime": {"count": 1, "max": 14.322996139526367, "sum": 14.322996139526367, "min": 14.322996139526367}, "update.time": {"count": 3, "max": 774.3468284606934, "sum": 2230.764865875244, "min": 723.5779762268066}, "epochs": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1548184299.895695, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1548184297.3801}
# 2019-01-22 19:11:49 Uploading - Uploading generated training model
# 2019-01-22 19:11:49 Completed - Training job completed
# Billable seconds: 43

# %%
lin_predictor = linear.deploy(initial_instance_count=1,
                           instance_type='ml.t2.medium')
# Out:
# INFO:sagemaker:Creating model with name: linear-learner-2019-01-22-19-02-17-848
# INFO:sagemaker:Creating endpoint with name linear-learner-2019-01-22-18-56-24-284
# ---------------------------------------------------------------------------!

# %%
matchup = [1471,1328,0.272,0.5,0.291,0.2]

1471
1328
0.272
0.5
0.291
0.2

endpoint_name = 'linear-learner-2019-01-22-18-30-14-101'
predictor = sagemaker.predictor.RealTimePredictor(endpoint=endpoint_name,   #create predictor to send serialized data to sagemaker
                                                serializer=sagemaker.predictor.csv_serializer,
                                                content_type='text/csv')
endpoint_name_2 = 'linear-learner-2019-01-15-00-14-22-386'
predictor_2 = sagemaker.predictor.RealTimePredictor(endpoint=endpoint_name_2,   #create predictor to send serialized data to sagemaker
                                                serializer=sagemaker.predictor.csv_serializer,
                                                content_type='text/csv')

endpoint_name_3 = 'linear-learner-2019-01-22-18-56-24-284'
predictor_3 = sagemaker.predictor.RealTimePredictor(endpoint=endpoint_name_3,   #create predictor to send serialized data to sagemaker
                                                serializer=sagemaker.predictor.csv_serializer,
                                                content_type='text/csv')

response = predictor.predict(matchup)
response_2 = predictor_2.predict(matchup)
response_3 = predictor_3.predict(matchup)

# %%
response
# Out:
# b'{"predictions": [{"score": 2.607135772705078}]}'

# %%
response_2
# Out:
# b'{"predictions": [{"score": 1.9811859130859375}]}'

# %%
response_3
# Out:
# b'{"predictions": [{"score": 0.8397684097290039}]}'
